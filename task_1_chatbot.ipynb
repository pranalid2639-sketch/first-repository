# %% [markdown]
# <a href="https://colab.research.google.com/github/pranalid2639-sketch/first-repository/blob/main/task_1_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chatbot_response(user_input):
    user_input = user_input.lower()

    if "hello" in user_input or "hi" in user_input:
        return "Hello! How can I assist you today?"
    elif "who are you" in user_input:
        return "I am a simple rule-based chatbot created for the CODSOFT AI internship."
    elif "weather" in user_input:
        return "I can’t fetch live weather yet, but it’s always a good day to learn AI!"
    elif "codsoft" in user_input:
        return "CodSoft is a community-focused platform offering internships and learning opportunities."
    elif "help" in user_input:
        return "Sure! Tell me what you need help with."
    elif "bye" in user_input or "exit" in user_input:
        return "Goodbye! Have a nice day!"
    else:
        return "I'm not sure how to respond to that, but I’m learning every day!"

print("Chatbot is now running! Type 'bye' or 'exit' to stop.\n")

while True:
    user_text = input("You: ")
    response = chatbot_response(user_text)
    print("Bot:", response)

    if "bye" in user_text.lower() or "exit" in user_text.lower():
        break
# Out:
# Chatbot is now running! Type 'bye' or 'exit' to stop.
#
# You: hello
# Bot: Hello! How can I assist you today?
# You: who are you
# Bot: I am a simple rule-based chatbot created for the CODSOFT AI internship.
# You: codsoft
# Bot: CodSoft is a community-focused platform offering internships and learning opportunities.
# You: bye
# Bot: Goodbye! Have a nice day!
